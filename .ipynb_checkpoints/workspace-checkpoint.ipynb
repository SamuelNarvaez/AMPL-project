# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from music21 import *

# %%
centones = pd.read_csv("centones.csv")
centones.columns = ['istihlal','iraq arab','maya','sika','gharibat husayn']
relevant_centones = centones[['istihlal','maya','gharibat husayn']]
centones
# Out:
#       istihlal   iraq arab                 maya        sika gharibat husayn
# 0      E, F, G     E, F, G             B-, A, G     C, D, E         F, E, D
# 1      G, F, E     C, D, E              E, F, G        A, G         E, F, G
# 2   C, B, A, G  F, E, D, C              B, D, C     E, F, G            A, G
# 3         A, G        A, G                 A, G        G, E            G, E
# 4         E, D        D, C                 C, E        G, A         B, C, D
# 5         F, E        C, D                 B, C  E, F, D, E   B, D, C, B, A
# 6         G, F     A, B, C              G, F, E     E, D, C         E, D, C
# 7   E, F, A, G        F, E  F, G, E, F, E, D, C     G, F, E         C, D, E
# 8      F, E, D         NaN                  NaN         NaN         G, F, E
# 9      A, B, C         NaN                  NaN         NaN      E, F, D, E
# 10        D, C         NaN                  NaN         NaN             NaN
# 11  F, E, D, C         NaN                  NaN         NaN             NaN

# %%
lookup = {tab : [stream.Stream() for i in range(centones[tab].count())] for tab in centones.columns }
for tab in centones.columns:
    for i in range(centones[tab].count()):
        lookup[tab][i].append([note.Note(j) for j in centones[tab][i].split(", ")])

# %%
lookup['istihlal'][0].show()

# %%
lookup['sika'][7].show()

# %%
music = converter.parse("SCORES/1ab3fe6b-0f46-4584-9abc-733d59c25c1b.xml")
#music.show()
full_piece_stream = music.recurse().notes
numoccur = pd.DataFrame([[len(search.noteNameSearch(full_piece_stream, motif)) for motif in lookup[tab]]for tab in centones.columns]).T
numoccur.columns = centones.columns

# %%
numoccur
# Out:
#     istihlal  iraq arab  maya  sika  gharibat husayn
# 0       14.0       14.0   0.0  28.0             29.0
# 1       15.0       28.0  14.0   0.0             14.0
# 2        0.0       29.0   0.0  14.0              0.0
# 3        0.0        0.0   0.0  11.0             11.0
# 4       85.0       56.0   0.0   0.0              6.0
# 5       97.0       28.0   7.0   0.0              0.0
# 6       15.0        0.0  15.0  29.0             29.0
# 7        0.0       97.0   0.0  15.0             28.0
# 8       29.0        NaN   NaN   NaN             15.0
# 9        0.0        NaN   NaN   NaN              0.0
# 10      56.0        NaN   NaN   NaN              NaN
# 11      29.0        NaN   NaN   NaN              NaN

# %%
numoccur.sum().plot(title="num occurences of centones by tab",kind='bar')
# Out:
# <AxesSubplot:title={'center':'num occurences of centones by tab'}>

# %%
plt.barh(y=centones['istihlal'].values, width=numoccur['istihlal'].values)
# Out:
# <BarContainer object of 12 artists>

# %%
metadata = []
for filename in os.listdir('SCORES'):
    f = os.path.join('SCORES', filename)
    try:
        title = pd.read_xml(f)['movement-title'][0]
        if title == 'Mshalia Isbahan_Tetuán':
            if pd.read_xml(f)['credit-words'][3] != 'Tradicional':
                title = pd.read_xml(f)['credit-words'][3]
    except:
            try:
                if pd.read_xml(f)['credit-words'][2] != 'Tradicional':
                    title = pd.read_xml(f)['credit-words'][2]
                else:
                    title = np.nan
            except:
                title = np.nan
    metadata.append([filename,title])
metadata = pd.DataFrame(metadata,columns=['filename','title'])

# %%
metadata.describe()
# Out:
#                                         filename                   title
# count                                        159                     157
# unique                                       159                      89
# top     dae13b1f-b7fd-4db3-af3c-11784d51d829.xml  Mshalia Isbahan_Tetuán
# freq                                           1                      31

# %%
#pd.read_xml(f"SCORES/{metadata[metadata['title']=='Mshalia Isbahan_Tetuán'].filename.values[0]}")

# %%
istihlal_files = metadata[metadata['title'].str.lower().str.contains('istihlal').fillna(False)].copy()
maya_files = metadata[metadata['title'].str.lower().str.contains('maya').fillna(False)].copy()
gharibat_files = metadata[metadata['title'].str.lower().str.contains('gharibat').fillna(False)].copy()

# %%
istihlal_files['tab'] = 'istihlal'
maya_files['tab'] = 'maya'
gharibat_files['tab'] = 'gharibat husayn'

# %%
relevant_files = pd.concat([istihlal_files,maya_files,gharibat_files])

# %%
relevant_files['mizan'] = relevant_files.apply(lambda x: x.title.lower().replace(x.tab,''), axis=1)
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('.mp3',''))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace(' al-',''))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('_fes',''))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('raml',''))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('_rabat',''))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('_',''))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('gharibat',''))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('husain',''))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('bawakir',''))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: ''.join(i for i in x if not i.isdigit()))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('qaimwanisf','qaim wa nisf'))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('mchalia','mshalia'))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('qouddam','quddam'))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('qddam','quddam'))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('btaihi','btayhi'))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('darj','dary'))
relevant_files['mizan'] = relevant_files['mizan'].apply(lambda x: x.replace('bassit','basit'))
relevant_files = relevant_files.append(relevant_files.iloc[36])
relevant_files = relevant_files.reset_index().drop('index',axis=1)
relevant_files.iloc[36].mizan = 'btayhi'
relevant_files.iloc[43].mizan = 'quddam'
# Out:
# <ipython-input-16-67f40c1699ac>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   relevant_files = relevant_files.append(relevant_files.iloc[36])

# %%
relevant_files
# Out:
#                                     filename                       title  \
# 0   4342021d-03a1-4727-8c0f-3c23180ef374.xml            Mshalia Istihlal
# 1   b3d92934-0946-4f2d-8183-312450d7e45e.xml            Mshalia Istihlal
# 2   9727ddbe-eb79-461b-9861-8a60336b17f6.xml            Mshalia Istihlal
# 3   a1eac726-208e-4c24-bd57-e34e9e93dcd3.xml             Quddam Istihlal
# 4   6fe7108c-4e4f-457b-a363-ccf505bdee9a.xml             Btayhi Istihlal
# 5   2d2683c4-4b3e-4430-a254-c828427bdcc7.xml          Quddam al-Istihlal
# 6   44183247-4857-40cd-82bc-b4e9e3f458f1.xml            Mshalia Istihlal
# 7   3e5a82a2-d806-45cc-876e-6fa8a2b5a61d.xml            Mshalia Istihlal
# 8   023b4a37-1ab4-4593-b03a-850ee0db8350.xml      QaimWaNisfistihlal1982
# 9   f461045b-50bc-4b20-a731-66fbd3a264ae.xml            Qouddam Istihlal
# 10  cb85269e-ab6c-4226-aea1-8226be1fe86c.xml      QaimWaNisfistihlal1982
# 11  d4cadf34-1074-44ce-9928-f438198d5d6d.xml       Qaim Wa Nisf Istihlal
# 12  dae13b1f-b7fd-4db3-af3c-11784d51d829.xml      BtayhiRamlMaya_Fes.mp3
# 13  3a578e21-46bb-47f2-9a4d-7cd738f0dd5b.xml             2BtaihiRamlMaya
# 14  69ac4f1a-eca5-42eb-9f9c-a1c2316cb040.xml             3BtaihiRamlMaya
# 15  a451a7fc-c53f-462a-b3fc-4377bb588105.xml                 Btaihi_Maya
# 16  2d91d7e4-904a-46b7-bce2-230ca4e1b1c4.xml           BasitRamlMaya1987
# 17  8842c1f0-e261-4069-bd59-768bb9a3315c.xml                DarjMaya_Fes
# 18  277bc427-16dd-4468-9f4c-16945ffc3b30.xml                 Bassit Maya
# 19  1ffa4dee-b08e-4332-a2ab-9843c13c3dfa.xml         QouddamRamlMaya.mp3
# 20  62acb9e5-e311-40ab-9c5c-866d071b5c93.xml          QaimWaNisfMaya_Fes
# 21  d5cc773e-9d31-42e8-b9de-91374fe7153b.xml         QouddamRamlMaya.mp3
# 22  1f623914-8002-4866-8a6e-4dc684e848d9.xml              BassitMaya_Fes
# 23  b485548d-6b46-48aa-835f-1326f06bb91f.xml           BasitRamlMaya.mp3
# 24  c462ca37-7812-4b9b-9865-275da1f237fe.xml                 Btaihi_Maya
# 25  2cf367de-583b-4bd6-83f3-fc036fe19fab.xml           BasitRamlMaya.mp3
# 26  7448d9c2-5261-4e70-bd98-6ed8416f908f.xml                BassitMaya85
# 27  47a41543-89c7-40ad-a665-f7460ad4e4de.xml         2QaimWaNisfRamlMaya
# 28  f7bcb9af-6abb-4192-ae3d-37fa811034ce.xml          QouddamiMaya_Rabat
# 29  f7c00e6e-7b07-47ba-bfdd-146ddbf9adb5.xml                 Btaihi_Maya
# 30  99004770-1152-4fec-802a-a0014e9b9930.xml      QaimWaNisfRamlMaya_Fes
# 31  545dd98f-9667-4299-b967-71e0a2a3c883.xml                 Bassit Maya
# 32  13a8d4b9-8dbf-40c0-98df-db64791e43a9.xml           Mchalia Raml Maya
# 33  47e023e5-62a3-4dec-b61a-128ca5e23982.xml        BassitRamlMaya_Rabat
# 34  2083676f-c26b-4e2e-8324-1b571e729521.xml            Quddam Raml maya
# 35  7a5cc189-4962-42d0-8141-d1374e933e46.xml           QddamRamlMaya.mp3
# 36  0386e377-7212-43e5-89b6-7f4c42d0ae74.xml  Btayhi Quddam Bawakir Maya
# 37  b11237b9-d45b-4b3a-a97b-ab7d198f927f.xml                 QouddamMaya
# 38  a025eef0-d130-496f-9581-f5ce40bd1783.xml                 QouddamMaya
# 39  8361317d-2b4e-438f-9b73-d1daaa200a3e.xml        Btaihi Raml Maya.mp3
# 40  6311c0de-d66f-482d-8dd1-8d8917ca6a76.xml      Quddam Gharibat Husain
# 41  769ff214-27f4-4ac1-8750-a03015d51161.xml  QaimWaNisf Gharibat Husain
# 42  70c04adf-b886-4d62-a88a-abdde5d93715.xml      Bassit Gharibat Husayn
# 43  0386e377-7212-43e5-89b6-7f4c42d0ae74.xml  Btayhi Quddam Bawakir Maya
#
#                 tab           mizan
# 0          istihlal        mshalia
# 1          istihlal        mshalia
# 2          istihlal        mshalia
# 3          istihlal         quddam
# 4          istihlal         btayhi
# 5          istihlal          quddam
# 6          istihlal        mshalia
# 7          istihlal        mshalia
# 8          istihlal    qaim wa nisf
# 9          istihlal         quddam
# 10         istihlal    qaim wa nisf
# 11         istihlal   qaim wa nisf
# 12             maya          btayhi
# 13             maya          btayhi
# 14             maya          btayhi
# 15             maya          btayhi
# 16             maya           basit
# 17             maya            dary
# 18             maya          basit
# 19             maya          quddam
# 20             maya    qaim wa nisf
# 21             maya          quddam
# 22             maya           basit
# 23             maya           basit
# 24             maya          btayhi
# 25             maya           basit
# 26             maya           basit
# 27             maya    qaim wa nisf
# 28             maya         quddami
# 29             maya          btayhi
# 30             maya    qaim wa nisf
# 31             maya          basit
# 32             maya       mshalia
# 33             maya           basit
# 34             maya        quddam
# 35             maya          quddam
# 36             maya          btayhi
# 37             maya          quddam
# 38             maya          quddam
# 39             maya        btayhi
# 40  gharibat husayn        quddam
# 41  gharibat husayn  qaim wa nisf
# 42  gharibat husayn          basit
# 43             maya          quddam

# %%
relevant_centones
# Out:
#       istihlal                 maya gharibat husayn
# 0      E, F, G             B-, A, G         F, E, D
# 1      G, F, E              E, F, G         E, F, G
# 2   C, B, A, G              B, D, C            A, G
# 3         A, G                 A, G            G, E
# 4         E, D                 C, E         B, C, D
# 5         F, E                 B, C   B, D, C, B, A
# 6         G, F              G, F, E         E, D, C
# 7   E, F, A, G  F, G, E, F, E, D, C         C, D, E
# 8      F, E, D                  NaN         G, F, E
# 9      A, B, C                  NaN      E, F, D, E
# 10        D, C                  NaN             NaN
# 11  F, E, D, C                  NaN             NaN
