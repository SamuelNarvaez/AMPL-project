# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from music21 import *

# %%
centones = pd.read_csv("centones.csv")
centones
# Out:
#    #al-istihlal #iraq al-arab             #al-maya    #al-sika  \
# 0       E, F, G       E, F, G             B-, A, G     C, D, E
# 1       G, F, E       C, D, E              E, F, G        A, G
# 2    C, B, A, G    F, E, D, C              B, D, C     E, F, G
# 3          A, G          A, G                 A, G        G, E
# 4          E, D          D, C                 C, E        G, A
# 5          F, E          C, D                 B, C  E, F, D, E
# 6          G, F       A, B, C              G, F, E     E, D, C
# 7    E, F, A, G          F, E  F, G, E, F, E, D, C     G, F, E
# 8       F, E, D           NaN                  NaN         NaN
# 9       A, B, C           NaN                  NaN         NaN
# 10         D, C           NaN                  NaN         NaN
# 11   F, E, D, C           NaN                  NaN         NaN
#
#    #garibat al-husayn
# 0             F, E, D
# 1             E, F, G
# 2                A, G
# 3                G, E
# 4             B, C, D
# 5       B, D, C, B, A
# 6             E, D, C
# 7             C, D, E
# 8             G, F, E
# 9          E, F, D, E
# 10                NaN
# 11                NaN

# %%
lookup = {tab : [stream.Stream() for i in range(centones[tab].count())] for tab in centones.columns }
for tab in centones.columns:
    for i in range(centones[tab].count()):
        lookup[tab][i].append([note.Note(j) for j in centones[tab][i].split(", ")])

# %%
lookup['#al-istihlal'][0].show()

# %%
lookup['#al-sika'][7].show()

# %%
music = converter.parse("SCORES/1ab3fe6b-0f46-4584-9abc-733d59c25c1b.xml")
#music.show()
full_piece_stream = music.recurse().notes
numoccur = pd.DataFrame([[len(search.noteNameSearch(full_piece_stream, motif)) for motif in lookup[tab]]for tab in centones.columns]).T
numoccur.columns = centones.columns

# %%
music.metadata.show()

# %%
numoccur
# Out:
#     #al-istihlal  #iraq al-arab  #al-maya  #al-sika  #garibat al-husayn
# 0           14.0           14.0       0.0      28.0                29.0
# 1           15.0           28.0      14.0       0.0                14.0
# 2            0.0           29.0       0.0      14.0                 0.0
# 3            0.0            0.0       0.0      11.0                11.0
# 4           85.0           56.0       0.0       0.0                 6.0
# 5           97.0           28.0       7.0       0.0                 0.0
# 6           15.0            0.0      15.0      29.0                29.0
# 7            0.0           97.0       0.0      15.0                28.0
# 8           29.0            NaN       NaN       NaN                15.0
# 9            0.0            NaN       NaN       NaN                 0.0
# 10          56.0            NaN       NaN       NaN                 NaN
# 11          29.0            NaN       NaN       NaN                 NaN

# %%
numoccur.sum().plot(title="num occurences of centones by tab",kind='bar')
# Out:
# <AxesSubplot:title={'center':'num occurences of centones by tab'}>

# %%
plt.barh(y=centones['#al-istihlal'].values, width=numoccur['#al-istihlal'].values)
# Out:
# <BarContainer object of 12 artists>

# %%
metadata = []
for filename in os.listdir('SCORES'):
    f = os.path.join('SCORES', filename)
    try:
        title = pd.read_xml(f)['movement-title'][0]
        if title == 'Mshalia Isbahan_Tetuán':
            if pd.read_xml(f)['credit-words'][3] != 'Tradicional':
                title = pd.read_xml(f)['credit-words'][3]
    except:
            try:
                title = pd.read_xml(f)['credit-words'][2]
            except:
                title = np.nan
    metadata.append([filename,title])
metadata = pd.DataFrame(metadata,columns=['filename','title'])

# %%
metadata.describe()
# Out:
#                                         filename                   title
# count                                        159                     158
# unique                                       159                      90
# top     dae13b1f-b7fd-4db3-af3c-11784d51d829.xml  Mshalia Isbahan_Tetuán
# freq                                           1                      31

# %%
#pd.read_xml(f"SCORES/{metadata[metadata['title']=='Mshalia Isbahan_Tetuán'].filename.values[0]}")

# %%
metadata[metadata['title'].str.lower().str.contains('maya').fillna(False)]
# Out:
#                                      filename                       title
# 0    dae13b1f-b7fd-4db3-af3c-11784d51d829.xml      BtayhiRamlMaya_Fes.mp3
# 9    3a578e21-46bb-47f2-9a4d-7cd738f0dd5b.xml             2BtaihiRamlMaya
# 12   69ac4f1a-eca5-42eb-9f9c-a1c2316cb040.xml             3BtaihiRamlMaya
# 15   a451a7fc-c53f-462a-b3fc-4377bb588105.xml                 Btaihi_Maya
# 21   2d91d7e4-904a-46b7-bce2-230ca4e1b1c4.xml           BasitRamlMaya1987
# 33   8842c1f0-e261-4069-bd59-768bb9a3315c.xml                DarjMaya_Fes
# 35   277bc427-16dd-4468-9f4c-16945ffc3b30.xml                 Bassit Maya
# 45   1ffa4dee-b08e-4332-a2ab-9843c13c3dfa.xml         QouddamRamlMaya.mp3
# 48   62acb9e5-e311-40ab-9c5c-866d071b5c93.xml          QaimWaNisfMaya_Fes
# 62   d5cc773e-9d31-42e8-b9de-91374fe7153b.xml         QouddamRamlMaya.mp3
# 64   1f623914-8002-4866-8a6e-4dc684e848d9.xml              BassitMaya_Fes
# 67   b485548d-6b46-48aa-835f-1326f06bb91f.xml           BasitRamlMaya.mp3
# 68   c462ca37-7812-4b9b-9865-275da1f237fe.xml                 Btaihi_Maya
# 69   2cf367de-583b-4bd6-83f3-fc036fe19fab.xml           BasitRamlMaya.mp3
# 71   7448d9c2-5261-4e70-bd98-6ed8416f908f.xml                BassitMaya85
# 81   47a41543-89c7-40ad-a665-f7460ad4e4de.xml         2QaimWaNisfRamlMaya
# 83   f7bcb9af-6abb-4192-ae3d-37fa811034ce.xml          QouddamiMaya_Rabat
# 94   f7c00e6e-7b07-47ba-bfdd-146ddbf9adb5.xml                 Btaihi_Maya
# 98   99004770-1152-4fec-802a-a0014e9b9930.xml      QaimWaNisfRamlMaya_Fes
# 115  545dd98f-9667-4299-b967-71e0a2a3c883.xml                 Bassit Maya
# 122  13a8d4b9-8dbf-40c0-98df-db64791e43a9.xml           Mchalia Raml Maya
# 127  47e023e5-62a3-4dec-b61a-128ca5e23982.xml        BassitRamlMaya_Rabat
# 128  2083676f-c26b-4e2e-8324-1b571e729521.xml            Quddam Raml maya
# 135  7a5cc189-4962-42d0-8141-d1374e933e46.xml           QddamRamlMaya.mp3
# 140  0386e377-7212-43e5-89b6-7f4c42d0ae74.xml  Btayhi Quddam Bawakir Maya
# 146  b11237b9-d45b-4b3a-a97b-ab7d198f927f.xml                 QouddamMaya
# 152  a025eef0-d130-496f-9581-f5ce40bd1783.xml                 QouddamMaya
# 157  8361317d-2b4e-438f-9b73-d1daaa200a3e.xml        Btaihi Raml Maya.mp3

# %%
for i in metadata["title"]:
    print(i)
# Out:
# BtayhiRamlMaya_Fes.mp3
# Ma Khaba Qattu man sabar
# Mshalia Istihlal
# Mshalia Isbahan_Tetuán
# Mshalia Isbahan_Tetuán
# Mshalia Msharqi
# Mshalia Isbahan_Tetuán
# Mshalia Isbahan_Tetuán
# Mshalia
# 2BtaihiRamlMaya
# Qaim Wa Nisf Ouchaq
# Btayhi Rasd Dayl
# 3BtaihiRamlMaya
# Btaihi Iraq Ajam
# Ana Mani Fiyash
# Btaihi_Maya
# Nar Gdat Fi Qalbi
# Mshalia Ghariba Hussayn
# Mshalia Istihlal
# Btayhi Msharqi
# Mshalia Isbahan_Tetuán
# BasitRamlMaya1987
# Mshalia Isbahan_Tetuán
# Quddam Iraq Ajam
# Horm ya Rasul al Lah
# Ana Mzaweg
# Bassit Hijaz Mcharqi
# Mshalia Isbahan_Tetuán
# Mshalia Istihlal
# Mshalia Isbahan_Tetuán
# Mshalia Hiyaz Kabir
# Mshalia Msharqi
# Bassit Rasd Dayl
# DarjMaya_Fes
# Mshalia Isbahan_Tetuán
# Bassit Maya
# Tradicional
# Mshalia Hiyaz Kabir
# Mshalia Isbahan_Tetuán
# Ma Khaba Qattu man sabar
# Qouddam Isbahan
# BtayhiIsbahan.mp3
# Kol ly fi Wujudak
# BtayhiIsbahan.mp3
# Mshalia Isbahan_Tetuán
# QouddamRamlMaya.mp3
# Mshalia Isbahan_Tetuán
# Btayhi Rasd Dayl
# QaimWaNisfMaya_Fes
# Mchalia kbira
# Mshalia Oshaq
# Mshalia Isbahan_Tetuán
# Btaihi  Rasd
# QuddamUshaq
# Barwala Anes
# Quddam Istihlal
# QaimWaNisfIsbahan.mp3
# Btaihi  Rasd
# Btayhi Rasd Dayl
# Btayhi Istihlal
# Qouddam Rasd Dayl
# Mshalia Rasd Dayl
# QouddamRamlMaya.mp3
# Quddam al-Istihlal
# BassitMaya_Fes
